# %%
import pandas as pd

with open('FeMappingV9.json', encoding='utf-8') as inputfile:
    df = pd.read_json(inputfile)

# %%
df
# Out:
#       layer  MB  type  lpGBTs  \
# 0         1   0     0  [0, 1]
# 1         1   1     1     [2]
# 2         1   2     0     [3]
# 3         1   3     1     [4]
# 4         1   4     0     [5]
# ...     ...  ..   ...     ...
# 1276     50   0    11  [2163]
# 1277     50   0    11  [2164]
# 1278     50   0    11  [2165]
# 1279     50   0    11  [2166]
# 1280     50   0    11  [2167]
#
#                                                 modules
# 0     [{'u': 2, 'v': 0, 'elinks': [4, 0], 'shape': '...
# 1     [{'u': 5, 'v': 0, 'elinks': [1], 'shape': 'F'}...
# 2     [{'u': 4, 'v': 1, 'elinks': [2], 'shape': 'F'}...
# 3     [{'u': 6, 'v': 1, 'elinks': [1], 'shape': 'F'}...
# 4     [{'u': 3, 'v': 1, 'elinks': [3], 'shape': 'F'}...
# ...                                                 ...
# 1276   [{'u': 15, 'v': 7, 'elinks': [5], 'shape': 'f'}]
# 1277   [{'u': 15, 'v': 8, 'elinks': [5], 'shape': 'F'}]
# 1278   [{'u': 15, 'v': 9, 'elinks': [5], 'shape': 'F'}]
# ...

# %%
df.to_csv('FEMappingV9.csv', encoding='utf-8', index=False)

# %%
df.to_csv('FEMappingV9.txt', header=None, index=None, sep=' ', mode='a')
